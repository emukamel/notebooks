# %% [markdown]
# 09/04/2014
# ===========
#
# This is my first lab notebook entry.
#
# Activity-Dependent mRNA Transport:
# ---------------
# * I have hacked together some code to model activity-dependent transport of mRNA along a cable/dendrite. The code is pretty simple, and available in [this directory](http://nbviewer.ipython.org/github/ahwillia/notebooks/tree/master/arcmodel/2014_09_04).
# * Need to clean code up next week
# * Email Tim for feedback
#
# QuantNeuro Stuff
# ----------------
# * Made a [collapsible tree](http://bl.ocks.org/mbostock/4339083) to summarize the various aspects of homeostatic plasticity. I'm not sure how useful this will be...
# * I would really like to make an interactive diagram for the molecular pathways involved in homeostasis using d3. This could be very time consuming and not worth the effort.
# * Need to figure out an appropriate timeline to upload the first pass of the website.
# * Need to finish video for Chapter 2
#
# Other things on my mind:
# ---------------
# * This [mpld3](http://mpld3.github.io/) library blows my mind. I need to learn how to use it.
# * I've been coding in Julia lately and the speed-up has been great. However, I was previously unaware about the `%%julia` magic function, which might improve my workflow even further. See [this link](http://stackoverflow.com/questions/24091373/best-way-to-run-julia-code-in-an-ipython-notebook-or-python-code-in-an-ijulia-n) for more information.
# * In the future, there are plans to integrate julia, python, R, etc. into a common notebook environment called [Jupyter](http://jupyter.org/)
#
# -----------------------

# %% [markdown]
# 09/08/2014
# ===========
#
# Second entry. I have a week off before grad school bootcamp starts.
#
# Activity-Dependent mRNA Transport:
# ---------------
# * Code is now a bit cleaner. I made $\alpha$ a state variable, which makes things more consistent.
# * Steady-state functions are now sigmoids, rather than rectified lines
# * Code runs pretty quickly with 20 compartments
# * The next step was to implement negative feedback into the model. See [this notebook](http://nbviewer.ipython.org/github/ahwillia/notebooks/tree/master/arcmodel/2014_09_08/LocalRule_v4_closeLoop.ipynb)
#
# QuantNeuro Stuff
# ----------------
# * Need to figure out an appropriate timeline to upload the first pass of the website.
# * Still need to finish video for Chapter 2
#
# Other things on my mind:
# ---------------
# * Played around with [mpld3](http://mpld3.github.io/) a bit more. I developed a [slider demo](http://nbviewer.ipython.org/github/ahwillia/notebooks/tree/master/mpld3/2014_09_07/) that might be useful in the future.
# * One difficulty with making mpld3 truly interactive, is that any model will have to be coded in javascript because browsers can't run Python. I would really like to make interactive NEURON figures in iPython notebook... I think the only way to do this is detailed here: http://jakevdp.github.io/blog/2013/12/05/static-interactive-widgets/
#
# -----------------------

# %% [markdown]
# 09/09/2014
# ===========
#
# Activity-Dependent mRNA Transport:
# ---------------
# * I've now implemented homeostatic feedback that depends on mRNA level (not directly on calcium). See [This Notebook](http://nbviewer.ipython.org/github/ahwillia/notebooks/tree/master/arcmodel/2014_09_09/mRNA_Hill.ipynb)
# * So far compensation is incomplete, suggesting proportional control
#
# QuantNeuro Stuff
# ----------------
# * Wrote introduction to synapses/solutes
#
#
# -----------------------

# %% [markdown]
# 09/10/2014
# =======================
#
# Activity-Dependent mRNA Transport:
# ---------------
# * Recent code in [This Directory](http://nbviewer.ipython.org/github/ahwillia/notebooks/tree/master/arcmodel/2014_09_10/)
# * What are the unintuitive/interesting features of this model?
#     * Oscillations - Molecular Biology tends to present a static view of homeostatic processes due to experimental constraints. One of the interesting considerations that might be overlooked is that if substantial delays exist between the sensor and actuator in homeostatic systems, you can get oscillations around the set point.
#         * Can calcium-dependent transcription/RNA degradation prevent these sorts of oscillations?
#         * How do control theorists deal with these kinds of delays? [Feed-forward connections](http://www.chaos.gwdg.de/~kolo/JugendForscht/Control_tutorial.pdf), [Adaptive Control](https://www.youtube.com/watch?v=pU5vq6rjmKk)
#     * mRNA concentration gradient returns to normal (almost flat) after homeostatic compensation occurs. What kinds of data have been collected on this aspect of, e.g., *Arc* expression. Molecular biology seems to be biased towards the initial production and trafficking of mRNA, but I am not aware of much work on the "return to normalcy."
#
# --------------------

# %% [markdown]
# 09/12/2014
# =======================
#
# NEURON tools in Python:
# ---------------
# * I'd like to write functions using mpld3 for [shape plots](http://www.neuron.yale.edu/neuron/static/docs/zclass/shape.gif)
# * Some code below shows how to iterate over all sections and access their coordinates. I also made a simple 2D plot.
# * How hard would it be to have the color of the lines represent voltage over time?
# * Need to break up the line by the number of segments in the recording.
#
# QuantNeuro stuff
# --------------------
# * Another nice website: http://triangleinequality.wordpress.com/contents/

# %%
## Printing all pt3d points in python
from neuron import h

dend1 = h.Section()
dend2 = h.Section()
dend3 = h.Section()

h.pt3dadd(0,0,0,1,sec=dend1)
h.pt3dadd(1,0,0,1,sec=dend1)
h.pt3dadd(0,0,0,1,sec=dend3)
h.pt3dadd(0,1,0,1,sec=dend3)

for s in h.allsec():
    print '-------------------------------------------'
    print 'Printing coordinates for '+ h.secname(sec=s)
    print '-------------------------------------------'
   
    n3d = int(h.n3d(sec=s))
    x = []
    y = []
    if n3d == 0:
        print '  * No coordinates found *  '
        continue
    for i in range(0,n3d):
        print '--- i: ' + str(i) + ' ---'
        print 'x:  ' + str(h.x3d(i,sec=s))
        print 'y:  ' + str(h.y3d(i,sec=s))
        print 'z:  ' + str(h.z3d(i,sec=s))
        x.append(h.x3d(i,sec=s))
        y.append(h.y3d(i,sec=s))
# Out:
# -------------------------------------------
# Printing coordinates for PySec_0x3276720
# -------------------------------------------
# --- i: 0 ---
# x:  0.0
# y:  0.0
# z:  0.0
# --- i: 1 ---
# x:  1.0
# y:  0.0
# z:  0.0
# -------------------------------------------
# Printing coordinates for PySec_0x3276a50
# -------------------------------------------
#   * No coordinates found *
# -------------------------------------------
# Printing coordinates for PySec_0x3276ab0
# -------------------------------------------
# --- i: 0 ---
# x:  0.0
# y:  0.0
# z:  0.0
# --- i: 1 ---
# x:  0.0
# y:  1.0
# z:  0.0

# %% [markdown]
# 09/13/2014
# =======================
#
# PyNeuronToolbox:
# ---------------
# * The mpld3 angle might be a little premature, but we can still make some pretty cool animations.
# * I've successfully been able to make rough "shape plots" of neural morphology in matplotlib and make animations showing the propagation of action potentials
# * One thing that needs to be improved is the width of the lines. Right now all branches in the morphology are given equal widths, but width should be some function of diameter ideally
# * Demos/code can be tracked in [this Directory](http://nbviewer.ipython.org/github/ahwillia/notebooks/tree/master/PyNeuronToolbox/)
#
# ----------------------------------

# %% [markdown]
# 09/15/2014
# =======================
#
# UCSD boot camp day #1
#
# PyNeuronToolbox:
# ---------------
# * Need to implement: label locations on shape plot with markers
# * Need to implement: `record_ca`
#
# ----------------------------------

# %% [markdown]
# 09/17/2014
# =======================
#
# UCSD boot camp day #3
#
# Axonal Transport (Roy):
# ---------------
# * Proteins / Tools
#     * Synapsin-GFP
#     * Bassoon-GFP
# * Photo-activatable GFP tag
#     * Localized pulse-chase experiment
# * Super-pool is not activity-dependent (pre-synaptic)
# * Similar situation in dendrites
#
# Py-Neuron Toolbox To Do:
# ------------------
# * 2D projections
# * Circles around soma
# * Morphoelectric transforms
# * Line Widths
#
# ----------------------------------

# %% [markdown]
# 09/23/2014
# =======================
#
# Bootcamp Notes on Faculty
# ---------------------
# * **Jeffrey Goldberg** - Retina homeostasis/degeneration
# * **Axel Nimmerjahn** - Schnitzer Scope experiments
# * **Gentner and Sharpee** - Mosiac Receptive Fields
#     * How is this done? [Sharpee et al. (2006)](http://papers.cnl-t.salk.edu/PDFs/Adaptive%20filtering%20enhances%20information%20transmission%20in%20visual%20cortex%202006-4143.pdf)
# * **Nicola Allen** - Astrocyte regulation of synaptic plasticity
#     * RNAseq on astrocytes in response to various activation patterns
#         * Purification of astrocyte mRNA that is attached to ribosomes
#     * Retina Ganglion cell culture... Is there homeostasis in these cultures?
#     * Biochemical techniques to fractionate different secreted factors from astrocytes... Could this be used to separate neuropeptides?
# * **Sam Pfaff** - motor pools in spinal cord
#     * *c-Fos* and learning in the isolated spinal cord
# * **Gert Cauwenbergs** - chips with many "integrate-and-fire" neurons
#     * Actually have some intrinsic excitability as well, based on Hodgkin-Huxley equations
# * Lab studying emotion and using cFos to label olfactory neurons
#
# Papers to Read
# ================
# * Reviews
#     * [Dendritic mRNA: transport, translation and function](http://www.ncbi.nlm.nih.gov/pubmed/17848965)
#     * [Dendritic ion channel trafficking and plasticity](http://people.musc.edu/~woodward/Shah.pdf)
# * Hippocampal single-cell stuff
#     * Makara and Magee (2013). [Variable Dendritic Integration in Hippocampal CA3 Pyramidal Neurons](http://www.sciencedirect.com/science/article/pii/S0896627313009859)
#     * Hoffman (2013) [K+ Channel Regulation of Multicompartmental Signal Integration](http://www.sciencedirect.com/science/article/pii/S0896627313006417)
#     * Nestor and Hoffman (2012) [Differential cycling rates of Kv4.2 channels in proximal and distal dendrites of hippocampal CA1 pyramidal neurons](http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3134164/)
#     * Kim et al. (2007) [Regulation of Dendritic Excitability by Activity-Dependent Trafficking of the A-Type K+ Channel Subunit Kv4.2 in Hippocampal Neurons](http://www.cell.com/neuron/abstract/S0896-6273%2807%2900383-2)
#     * Jung and Hoffman (2009) [Biphasic somatic A-type K channel downregulation mediates intrinsic plasticity in hippocampal CA1 pyramidal neurons.](http://www.plosone.org/article/info%3Adoi%2F10.1371%2Fjournal.pone.0006549)
#
# ----------------------
